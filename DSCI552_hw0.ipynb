# %%
import pandas as pd

# %%
data = pd.read_csv('Salaries.csv',index_col = 'playerID', header = 0, skiprows = [1])

# %%
selected_players = data[((data.teamID == 'ATL') | (data.teamID == 'HOU')) & (data.salary >= 1000000)]

# %%
print(selected_players)
# Out:
#            yearID teamID lgID   salary
# playerID
# hornebo01    1985    ATL   NL  1500000
# murphda05    1985    ATL   NL  1625000
# suttebr01    1985    ATL   NL  1354167
# ryanno01     1985    HOU   NL  1350000
# hornebo01    1986    ATL   NL  1800000
# ...           ...    ...  ...      ...
# rasmuco01    2015    HOU   AL  8000000
# singljo02    2015    HOU   AL  2000000
# sippto01     2015    HOU   AL  2400000
# thatcjo01    2015    HOU   AL  1000000
# valbulu01    2015    HOU   AL  4200000
#
# [625 rows x 4 columns]

# %%
data_ATL = data[(data.teamID == 'ATL')]

# %%
data_ATL.describe()
# Out:
#             yearID        salary
# count   885.000000  8.850000e+02
# mean   1999.725424  2.207749e+06
# std       8.766470  3.434320e+06
# min    1985.000000  6.000000e+04
# 25%    1992.000000  3.000000e+05
# 50%    1999.000000  6.000000e+05
# 75%    2007.000000  2.400000e+06
# max    2015.000000  1.606180e+07

# %%
new_dataframe = pd.read_csv('Salaries.csv')

# %%
result = new_dataframe.to_dict('records')

# %%
df = pd.DataFrame(result)

# %%
df.columns = ['a','b','c','d','e']

# %%
print(df)
# Out:
#           a    b   c          d         e
# 0      1985  ATL  NL  barkele01    870000
# 1      1985  ATL  NL  bedrost01    550000
# 2      1985  ATL  NL  benedbr01    545000
# 3      1985  ATL  NL   campri01    633333
# 4      1985  ATL  NL  ceronri01    625000
# ...     ...  ...  ..        ...       ...
# 25570  2015  WAS  NL  treinbl01    512800
# 25571  2015  WAS  NL  ugglada01    507500
# 25572  2015  WAS  NL  werthja01  21000000
# 25573  2015  WAS  NL  zimmejo02  16500000
# 25574  2015  WAS  NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %%
import numpy as np

# %%
arr = np.array([[2,3],[1,4],[2,3]])

# %%
print(arr)
# Out:
# [[2 3]
#  [1 4]
#  [2 3]]

# %%
arr.ndim
#ndim = number of dimensions
# Out:
# 2

# %%
arr.shape
#shape = rows, columns
# Out:
# (3, 2)

# %%
arr.size
#size = number of rows * number of columns
# Out:
# 6

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.itemsize
# Out:
# 8

# %%
arr.data

# %%
arr.flatten()
# Out:
# array([2, 3, 1, 4, 2, 3])

# %%
arr.reshape(2,3)
#two elements, with 3D
# Out:
# array([[2, 3, 1],
#        [4, 2, 3]])

# %%
arr.reshape(3,2)
# Out:
# array([[2, 3],
#        [1, 4],
#        [2, 3]])

# %%
arr[1:,0:1]
# Out:
# array([[1],
#        [2]])

# %%
arr.argmin()
#Use min when you want to know what the smallest value in the array is.
#Use argmin when you want to know the location (index) of the smallest value in the array.
# Out:
# 2

# %%
arr.argmax()
# Out:
# 3

# %%
arr.min()
# Out:
# 1

# %%
arr.max()
# Out:
# 4

# %%
arr.mean(axis=1)
# Out:
# array([2.5, 2.5, 2.5])

# %%
arr.mean(axis=0)
#when axis=0, it means compute column wise
# Out:
# array([1.66666667, 3.33333333])

# %%
arr.sum()
#the sum of all elements
# Out:
# 15

# %%
arr.std()
# Out:
# 0.9574271077563381

# %%
arr1 = np.array([[3,5],[4,2],[1,5]])
#shape of arr1 is (3,2)

# %%
arr1_t = arr1.T

# %%
arrdot = np.dot(arr,arr1_t)

# %%
print(arrdot)
# Out:
# [[21 14 17]
#  [23 12 21]
#  [21 14 17]]

# %%
arr2 = np.array([[3,4,5],[1,2,3]])
#shape of arr2 is (2,3)

# %%
arrdot = np.dot(arr1,arr2)
#dot works if arr1 is of shape (m, n) and arr2 is of shape (n, p), np.dot(arr1, arr2) is valid and returns an array of shape (m, p).

# %%
print(arrdot)
# Out:
# [[14 22 30]
#  [14 20 26]
#  [ 8 14 20]]

# %%
arr3 = np.square(arr)

# %%
print(arr3)
# Out:
# [[ 4  9]
#  [ 1 16]
#  [ 4  9]]

# %%
arr4 = np.sqrt(arr)

# %%
print(arr4)
# Out:
# [[1.41421356 1.73205081]
#  [1.         2.        ]
#  [1.41421356 1.73205081]]

# %%
arr5 = np.abs(arr)

# %%
print(arr5)
# Out:
# [[2 3]
#  [1 4]
#  [2 3]]

# %%
arr6 = np.exp(arr)

# %%
print(arr6)
# Out:
# [[ 7.3890561  20.08553692]
#  [ 2.71828183 54.59815003]
#  [ 7.3890561  20.08553692]]

# %%
arr7 = np.sign(arr)

# %%
print(arr7)
# Out:
# [[1 1]
#  [1 1]
#  [1 1]]

# %%
arr8 = np.mod(arr,arr1)
#to use mod(),the same shape is needed and the result is arr%arr1. it can also be used as arr% a particular number

# %%
print(arr8)
# Out:
# [[2 3]
#  [1 0]
#  [0 3]]

# %%
arr9 = np.arange(2,10,2)

# %%
print(arr9)
# Out:
# [2 4 6 8]

# %%
arr10 = np.ones((2,3))

# %%
print(arr10)
# Out:
# [[1. 1. 1.]
#  [1. 1. 1.]]

# %%
arr11 = np.ones((2,3),dtype = np.int32)

# %%
print(arr11)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
arr12 = np.zeros((2,3))

# %%
print(arr12)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
arr13 = np.eye(3)

# %%
print(arr13)
# Out:
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
arr14 = np.linspace(0, 10, num=5, endpoint=False)

# %%
print(arr14)
# Out:
# [0. 2. 4. 6. 8.]

# %%
arr15 = np.array([[1, 2], [3, 4]])
arr16 = np.array([[5, 6], [7, 8]])

result = np.concatenate((arr15, arr16), axis=0)
#In NumPy, the concatenate() function is used to join two or more arrays along an existing axis. This function is useful for combining data that is spread across multiple arrays into a single array for easier processing and analysis.
print(result)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5,5,num=20)
y = np.array([j**2 for j in x])

# %%
plt.plot(x,y)
plt.xlabel('x') Sabrina call Michelle what are you when we get this like last week no
plt.ylabel('y')
plt.show()

# %%
x = np.linspace(-5,5,num=20)
y1 = np.array([j for j in x])
y2 = np.array([j**2 for j in x])
y3 = np.array([j**3 for j in x])

fig,(ax1,ax2,ax3) = plt.subplots(3)
ax1.plot(x,y1)
ax2.plot(x,y2)
ax3.plot(x,y3)
plt.show()

# %%
x = np.linspace(-5,5,num=20)
y1 = np.array([j for j in x])
y2 = np.array([j**2 for j in x])
y3 = np.array([j**3 for j in x])

fig,(ax1,ax2,ax3) = plt.subplots(3,figsize = (9.5,5.5))
fig.suptitle('Vertically stacked subplots')

csfont = {'fontname':'Comic Sans MS'}
hfont = {'fontname':'Helvetica'}

plt.title('Vertically stacked subplots',**csfont)
plt.xlabel('x',**hfont)

ax1.plot(x,y1)
ax2.plot(x,y2)
ax3.plot(x,y3)

plt.show()

# %%
x = np.linspace(-5,5,num=20)
y = np.array([j**2 for j in x])

fig,ax = plt.subplots()
ax.plot(x,y)

ax.set_xscale('log')
ax.set_yscale('log')

plt.xlabel('logx')
plt.ylabel('logy')

plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

var_set = ["year_ID","teamID","lgID","playerID","salary"]
head_set = []
head_set.extend(var_set)
head_set.append("num_feat")

df = pd.read_csv('Salaries.csv', index_col = 'playerID', header = None, names = head_set)
df['num_feat'] = 100 * np.random.random_sample(df.shape[0])

df_copy = df
cols_with_team_ATL = df_copy.loc[df_copy.teamID == 'ATL', ]

pairplot_fig = sns.pairplot(cols_with_team_ATL, vars = ['year_ID', 'salary', 'num_feat'])
plt.subplots_adjust(top = 0.9)
pairplot_fig.fig.suptitle("Scatter plots among numeric features in the data frame for teamID = ATL",fontsize = 18, alpha = 0.9, weight = 'bold')

plt.show()
# Out:
# /Users/ansleyleung/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

cols_with_year_1985 = df_copy.loc[df_copy.year_ID == "1985", ]
cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)

fig,ax = plt.subplots(figsize = (7,5))
sns.boxplot(x = 'teamID', y = 'salary', data = cols_with_year_1985, orient = 'v')
fig.subplots_adjust(top = 0.9)
ax.text(x=0.5, y=1.1, s="Boxplot of salary distribution for the year 1985 for each team", fontsize = 16,weight = 'bold', ha = 'center', va='bottom', transform=ax.transAxes)
# Out:
# /tmp/ipykernel_93296/3419089684.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)
# Text(0.5, 1.1, 'Boxplot of salary distribution for the year 1985 for each team')
